# %%
#Data Visualization
#Corelation heatmap
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
data=pd.read_csv('C:/Users/HP/Desktop/ArshiaJoshi/arshia_engineering/VSEC/user_behavior_dataset.csv')
#print(data)

# Assuming 'data' is your DataFrame
corr = data[['App Usage Time (min/day)', 'Screen On Time (hours/day)', 
             'Battery Drain (mAh/day)', 'Number of Apps Installed', 
             'Data Usage (MB/day)', 'Age']].corr()

# Plot the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize = (5,5))
sns.boxplot(x = data["App Usage Time (min/day)"],y = data["Battery Drain (mAh/day)"])
plt.title("App Usage Time vs Battery Drain")
plt.show()

# %%
# Plotting the histogram with KDE (Kernel Density Estimate)
sns.histplot(data=data['Data Usage (MB/day)'], bins=10, kde=True)

# Adding labels and title
plt.xlabel('Data Usage (MB/day)')
plt.ylabel('Frequency')
plt.title('Distribution of Data Usage (MB/day)')

# Show plot
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Screen On Time(hours/day)', y='Age', data=data)
plt.title('Screen On Time Vs Age')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 plt.figure(figsize=(5,5))
# ----> 2 sns.countplot(x='Screen On Time(hours/day)', y='Age', data=data)
#       3 plt.title('Screen On Time Vs Age')
#       4 plt.show()
#
# File ~\anaconda\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metric import accuracy_score,confusion_matrix,classification_report
from sklearn import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 from sklearn.preprocessing import StandardScaler
#       5 from sklearn.linear_model import LogisticRegression
# ----> 6 from sklearn.metric import accuracy_score,confusion_matrix,classification_report
#       7 from sklearn import datasets
#
# ModuleNotFoundError: No module named 'sklearn.metric'

# %%
import sklearn

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import datasets

# %%
data=pd.read_csv('C:/Users/HP/Desktop/vol.csv')
print(data.index)
print(data.columns)
print(data.shape)
data.info()
# Out:
# RangeIndex(start=0, stop=1571, step=1)
# Index(['Region', 'Number', 'Volcano Name', 'Country', 'Location', 'Latitude',
#        'Longitude', 'Elevation(m) ', 'Type', 'Status', 'Last Known Eruption'],
#       dtype='object')
# (1571, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region               1571 non-null   object
#  1   Number               1571 non-null   object
#  2   Volcano Name         1571 non-null   object
#  3   Country              1571 non-null   object
#  4   Location             1571 non-null   object
#  5   Latitude             1571 non-null   float64
#  6   Longitude            1571 non-null   float64
#  7   Elevation(m)         1566 non-null   float64
#  8   Type                 1571 non-null   object
#  9   Status               1571 non-null   object
# ...

# %%
x=data.iloc[:,0:90]
y=data['Latitude']
print(x)
print(y)
# Out:
#                         Region    Number         Volcano Name   Country  \
# 0                  West Indies  1600-21-               Piparo  Trinidad
# 1                  West Indies  1600-08=   Diables, Morne aux  Dominica
# 2                  West Indies  1600-09=    Diablotins, Morne  Dominica
# 3                  West Indies  1600-11=     Plat Pays, Morne  Dominica
# 4                  West Indies  1600-10=  Trois Pitons, Morne  Dominica
# ...                        ...       ...                  ...       ...
# 1566   Melanesia and Australia  0507-08-  NE Shepherd Islands   Vanuatu
# 1567   Melanesia and Australia  0507-081           North Vate   Vanuatu
# 1568   Melanesia and Australia  0507-01=          Suretamatai   Vanuatu
# 1569   Melanesia and Australia  0507-09=       Traitor's Head   Vanuatu
# 1570   Melanesia and Australia  0507-10=                Yasur   Vanuatu
#
#                 Location  Latitude  Longitude  Elevation(m)              Type  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Ensure X_train and X_test are DataFrames
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)

# One-hot encoding for categorical variables including 'Occupation'
categorical_columns = ['Type', 'Status','last Known Eruption']
                       
# Perform one-hot encoding before scaling
for column in categorical_columns:
    if column in x_train.columns:
        x_train = pd.get_dummies(x_train, columns=[column], drop_first=True)
        x_test = pd.get_dummies(x_test, columns=[column], drop_first=True)
                       
# Align columns in case of any missing categories
x_train, x_test = x_train.align(x_test, join='left', axis=1, fill_value=0)
                       
# Store feature names before scaling
feature_names = x_train.columns
                       
# Scale the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train) # Converts to NumPy array
x_test = scaler.transform(x_test) # Converts to NumPy array
                       
# At this point, feature_names is still available as a list
print(feature_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6836ceaeb43e> in <module>
#      23 # Scale the features
#      24 scaler = StandardScaler()
# ---> 25 x_train = scaler.fit_transform(x_train) # Converts to NumPy array
#      26 x_test = scaler.transform(x_test) # Converts to NumPy array
#      27
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# ...

# %%
log_reg=LogisticRegression(max_iter=200)
log_reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-7f55cdb2c346> in <module>
#       1 log_reg=LogisticRegression(max_iter=200)
# ----> 2 log_reg.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
y_pred=log_reg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-13-5bc65f17e8ee> in <module>
# ----> 1 y_pred=log_reg.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     280             class would be predicted.
#     281         """
# --> 282         check_is_fitted(self)
#     283
#     284         X = check_array(X, accept_sparse='csr')
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
# Calculate accuracy, confusion matrix, and classification report
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Output of results
print(f"Accuracy: {accuracy * 100:.2f}%")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-023ca78455dc> in <module>
#       1 from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
#       2 # Calculate accuracy, confusion matrix, and classification report
# ----> 3 accuracy = accuracy_score(y_test, y_pred)
#       4 conf_matrix = confusion_matrix(y_test, y_pred)
#       5 class_report = classification_report(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined
